# %%
import pandas  as pd
from pandas import read_csv
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=read_csv('../dataaaa/final_data.csv')

# df['Prix'] = pd.to_numeric(df['Prix'].str.replace(' ', ''), errors='coerce')

price=df['Prix']
# print(price)
marque=df['Marque']
print(marque) 
plt.scatter(price,marque)
plt.show()
# Out:
# 0       Mercedes-Benz
# 1             Peugeot
# 2               Mazda
# 3                Ford
# 4              Toyota
#             ...
# 2382             Opel
# 2383             Ford
# 2384       Volkswagen
# 2385        Chevrolet
# 2386          Renault
# Name: Marque, Length: 2387, dtype: object
